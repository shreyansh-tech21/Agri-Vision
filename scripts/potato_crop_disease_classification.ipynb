# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader

from sklearn.metrics import (
    classification_report,
    confusion_matrix
)

from tqdm import tqdm


# CONFIG

DATASET_PATH = r"refer to README for dataset details"

TRAIN_DIR = os.path.join(DATASET_PATH, "train")
VALID_DIR = os.path.join(DATASET_PATH, "valid")
TEST_DIR = os.path.join(DATASET_PATH, "test")

SAVE_DIR = r"Agri-Vision\models\potato_crop_disease_classification"
RESULTS_DIR = r"Agri-Vision\results\potato_crop_disease_classification"

os.makedirs(SAVE_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)

BATCH_SIZE = 32
IMAGE_SIZE = 224
EPOCHS = 15
LEARNING_RATE = 5e-6

DEVICE = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("Using device:", DEVICE)


# AUGMENTATION
train_transforms = transforms.Compose([

    transforms.RandomResizedCrop(
        IMAGE_SIZE,
        scale=(0.8, 1.0)
    ),

    transforms.RandomHorizontalFlip(),

    transforms.RandomRotation(25),

    transforms.RandomPerspective(
        distortion_scale=0.3,
        p=0.5
    ),

    transforms.ColorJitter(
        brightness=0.4,
        contrast=0.4,
        saturation=0.4
    ),

    transforms.GaussianBlur(
        kernel_size=3
    ),

    transforms.ToTensor(),

    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

val_test_transforms = transforms.Compose([

    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),

    transforms.ToTensor(),

    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])


# DATASETS

train_dataset = datasets.ImageFolder(
    TRAIN_DIR,
    transform=train_transforms
)

valid_dataset = datasets.ImageFolder(
    VALID_DIR,
    transform=val_test_transforms
)

test_dataset = datasets.ImageFolder(
    TEST_DIR,
    transform=val_test_transforms
)


# DATALOADERS

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2
)

valid_loader = DataLoader(
    valid_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2
)


# CLASS NAMES

class_names = train_dataset.classes

print("\nClasses:")

for idx, cls in enumerate(class_names):
    print(f"{idx}: {cls}")

NUM_CLASSES = len(class_names)



# LOAD RESNET50

model = models.resnet50(
    weights=models.ResNet50_Weights.IMAGENET1K_V2
)

model.fc = nn.Linear(
    model.fc.in_features,
    NUM_CLASSES
)

for param in model.parameters():
    param.requires_grad = False

for param in model.layer4.parameters():
    param.requires_grad = True

for param in model.fc.parameters():
    param.requires_grad = True

model = model.to(DEVICE)


# CLASS WEIGHTS

class_counts = np.bincount(train_dataset.targets)

class_weights = torch.tensor(
    1.0 / class_counts,
    dtype=torch.float
).to(DEVICE)


# LOSS + OPTIMIZER

criterion = nn.CrossEntropyLoss(
    weight=class_weights
)

optimizer = optim.Adam(
    filter(
        lambda p: p.requires_grad,
        model.parameters()
    ),
    lr=LEARNING_RATE
)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=2
)


# TRAIN FUNCTION

def train_one_epoch(model, loader):

    model.train()

    running_loss = 0
    correct = 0
    total = 0

    loop = tqdm(loader)

    for images, labels in loop:

        images = images.to(DEVICE)
        labels = labels.to(DEVICE)

        optimizer.zero_grad()

        outputs = model(images)

        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        _, predicted = outputs.max(1)

        total += labels.size(0)

        correct += predicted.eq(labels).sum().item()

        loop.set_description("Training")

        loop.set_postfix(
            loss=loss.item(),
            accuracy=100. * correct / total
        )

    epoch_loss = running_loss / len(loader)

    epoch_acc = 100. * correct / total

    return epoch_loss, epoch_acc


# VALIDATION FUNCTION

def validate(model, loader):

    model.eval()

    running_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in loader:

            images = images.to(DEVICE)
            labels = labels.to(DEVICE)

            outputs = model(images)

            loss = criterion(outputs, labels)

            running_loss += loss.item()

            _, predicted = outputs.max(1)

            total += labels.size(0)

            correct += predicted.eq(labels).sum().item()

    epoch_loss = running_loss / len(loader)

    epoch_acc = 100. * correct / total

    return epoch_loss, epoch_acc


# TRAINING LOOP

train_accuracies = []
val_accuracies = []

train_losses = []
val_losses = []

best_val_loss = float("inf")

for epoch in range(EPOCHS):

    print(f"\n========== Epoch {epoch+1}/{EPOCHS} ==========")

    train_loss, train_acc = train_one_epoch(
        model,
        train_loader
    )

    val_loss, val_acc = validate(
        model,
        valid_loader
    )

    scheduler.step(val_loss)

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    print(f"\nTrain Loss: {train_loss:.4f}")
    print(f"Train Accuracy: {train_acc:.2f}%")

    print(f"\nValidation Loss: {val_loss:.4f}")
    print(f"Validation Accuracy: {val_acc:.2f}%")

    if val_loss < best_val_loss:

        best_val_loss = val_loss

        torch.save(
            model.state_dict(),
            os.path.join(
                SAVE_DIR,
                "best_potato_resnet50.pth"
            )
        )

        print("\nBest model saved!")


# LOAD BEST MODEL

print("\nLoading best model...")

model.load_state_dict(
    torch.load(
        os.path.join(
            SAVE_DIR,
            "best_potato_resnet50.pth"
        ),
        map_location=DEVICE,
        weights_only=True
    )
)


# TEST EVALUATION

print("\n========== TESTING ==========")

test_loss, test_acc = validate(
    model,
    test_loader
)

print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2f}%")


# CLASSIFICATION REPORT

all_labels = []
all_predictions = []

model.eval()

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(DEVICE)

        outputs = model(images)

        _, predicted = outputs.max(1)

        all_labels.extend(labels.numpy())

        all_predictions.extend(
            predicted.cpu().numpy()
        )

print("\n========== CLASSIFICATION REPORT ==========")

report = classification_report(
    all_labels,
    all_predictions,
    target_names=class_names,
    zero_division=0
)

print(report)

report_path = os.path.join(
    RESULTS_DIR,
    "classification_report.txt"
)

with open(report_path, "w") as f:
    f.write(report)

print("\nClassification report saved!")


# CONFUSION MATRIX

cm = confusion_matrix(
    all_labels,
    all_predictions
)

plt.figure(figsize=(8, 6))

plt.imshow(cm)

plt.title("Confusion Matrix")

plt.colorbar()

plt.xticks(
    np.arange(len(class_names)),
    class_names,
    rotation=45
)

plt.yticks(
    np.arange(len(class_names)),
    class_names
)

for i in range(len(class_names)):
    for j in range(len(class_names)):

        plt.text(
            j,
            i,
            cm[i, j],
            ha="center",
            va="center"
        )

plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.tight_layout()

plt.savefig(
    os.path.join(
        RESULTS_DIR,
        "confusion_matrix.png"
    )
)

print("\nConfusion matrix saved!")


# ACCURACY CURVE
plt.figure(figsize=(8, 6))

plt.plot(
    train_accuracies,
    label="Train Accuracy"
)

plt.plot(
    val_accuracies,
    label="Validation Accuracy"
)

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("Accuracy Curve")

plt.legend()

plt.savefig(
    os.path.join(
        RESULTS_DIR,
        "accuracy_curve.png"
    )
)

print("\nAccuracy curve saved!")



# LOSS CURVE

plt.figure(figsize=(8, 6))

plt.plot(
    train_losses,
    label="Train Loss"
)

plt.plot(
    val_losses,
    label="Validation Loss"
)

plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.title("Loss Curve")

plt.legend()

plt.savefig(
    os.path.join(
        RESULTS_DIR,
        "loss_curve.png"
    )
)

print("\nLoss curve saved!")


# SAVE FULL MODEL
torch.save(
    model,
    os.path.join(
        SAVE_DIR,
        "full_resnet50_model.pth"
    )
)

print("\nTraining Complete!")

print("\nSaved Files:")
print("- best_potato_resnet50.pth")
print("- full_resnet50_model.pth")
print("- confusion_matrix.png")
print("- classification_report.txt")
print("- accuracy_curve.png")
print("- loss_curve.png")
# Out:
# Using device: cuda
#
# Classes:
# 0: Potato___Early_blight
# 1: Potato___Late_blight
# 2: Potato___healthy
#
# ========== Epoch 1/15 ==========
# Training: 100%|██████████| 48/48 [00:49<00:00,  1.03s/it, accuracy=41.6, loss=1.12]
# Train Loss: 1.0870
# Train Accuracy: 41.57%
#
# Validation Loss: 1.0700
# Validation Accuracy: 49.85%
#
# Best model saved!
#
# ========== Epoch 2/15 ==========
# Training: 100%|██████████| 48/48 [00:18<00:00,  2.64it/s, accuracy=59.9, loss=1.09]
# Train Loss: 1.0487
# Train Accuracy: 59.89%
#
# Validation Loss: 1.0423
# Validation Accuracy: 62.54%
#
# Best model saved!
#
# ========== Epoch 3/15 ==========
# Training: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s, accuracy=71.6, loss=1.08]
# Train Loss: 1.0004
# Train Accuracy: 71.65%
#
# Validation Loss: 0.9981
# Validation Accuracy: 73.99%
#
# Best model saved!
#
# ========== Epoch 4/15 ==========
# Training: 100%|██████████| 48/48 [00:17<00:00,  2.78it/s, accuracy=80.7, loss=0.974]
# Train Loss: 0.9415
# Train Accuracy: 80.74%
#
# Validation Loss: 0.9228
# Validation Accuracy: 78.33%
#
# Best model saved!
#
# ========== Epoch 5/15 ==========
# Training: 100%|██████████| 48/48 [00:17<00:00,  2.81it/s, accuracy=85.5, loss=0.923]
# Train Loss: 0.8537
# Train Accuracy: 85.52%
#
# Validation Loss: 0.8812
# Validation Accuracy: 82.66%
#
# Best model saved!
#
# ========== Epoch 6/15 ==========
# Training: 100%|██████████| 48/48 [00:17<00:00,  2.78it/s, accuracy=87.3, loss=1.05]
# Train Loss: 0.7591
# Train Accuracy: 87.25%
#
# Validation Loss: 0.7585
# Validation Accuracy: 82.35%
#
# Best model saved!
#
# ========== Epoch 7/15 ==========
# Training: 100%|██████████| 48/48 [00:17<00:00,  2.81it/s, accuracy=89.4, loss=0.954]
# Train Loss: 0.6436
# Train Accuracy: 89.44%
#
# Validation Loss: 0.6881
# Validation Accuracy: 89.47%
#
# Best model saved!
#
# ========== Epoch 8/15 ==========
# Training: 100%|██████████| 48/48 [00:17<00:00,  2.82it/s, accuracy=88.6, loss=0.787]
# Train Loss: 0.5429
# Train Accuracy: 88.58%
#
# Validation Loss: 0.5942
# Validation Accuracy: 86.69%
#
# Best model saved!
#
# ========== Epoch 9/15 ==========
# Training: 100%|██████████| 48/48 [00:17<00:00,  2.70it/s, accuracy=91.8, loss=0.943]
# Train Loss: 0.4548
# Train Accuracy: 91.77%
#
# Validation Loss: 0.5390
# Validation Accuracy: 91.95%
#
# Best model saved!
#
# ========== Epoch 10/15 ==========
# Training: 100%|██████████| 48/48 [00:16<00:00,  2.95it/s, accuracy=92, loss=0.689]
# Train Loss: 0.3940
# Train Accuracy: 91.97%
#
# Validation Loss: 0.4346
# Validation Accuracy: 90.71%
#
# Best model saved!
#
# ========== Epoch 11/15 ==========
# Training: 100%|██████████| 48/48 [00:16<00:00,  2.84it/s, accuracy=92.6, loss=0.785]
# Train Loss: 0.3428
# Train Accuracy: 92.63%
#
# Validation Loss: 0.3507
# Validation Accuracy: 90.40%
#
# Best model saved!
#
# ========== Epoch 12/15 ==========
# Training: 100%|██████████| 48/48 [00:16<00:00,  2.97it/s, accuracy=93, loss=0.398]
# Train Loss: 0.2972
# Train Accuracy: 93.03%
#
# Validation Loss: 0.3563
# Validation Accuracy: 92.57%
#
# ========== Epoch 13/15 ==========
# Training: 100%|██████████| 48/48 [00:16<00:00,  2.93it/s, accuracy=94, loss=0.31]
# Train Loss: 0.2615
# Train Accuracy: 94.02%
#
# Validation Loss: 0.2816
# Validation Accuracy: 95.67%
#
# Best model saved!
#
# ========== Epoch 14/15 ==========
# Training: 100%|██████████| 48/48 [00:15<00:00,  3.02it/s, accuracy=95.1, loss=0.459]
# Train Loss: 0.2245
# Train Accuracy: 95.09%
#
# Validation Loss: 0.2450
# Validation Accuracy: 94.12%
#
# Best model saved!
#
# ========== Epoch 15/15 ==========
# Training: 100%|██████████| 48/48 [00:17<00:00,  2.81it/s, accuracy=95.2, loss=0.493]
# Train Loss: 0.2161
# Train Accuracy: 95.15%
#
# Validation Loss: 0.2456
# Validation Accuracy: 93.50%
#
# Loading best model...
#
# ========== TESTING ==========
#
# Test Loss: 0.2617
# Test Accuracy: 95.05%
#
# ========== CLASSIFICATION REPORT ==========
#                        precision    recall  f1-score   support
#
# Potato___Early_blight       0.99      0.95      0.97       150
#  Potato___Late_blight       0.98      0.94      0.96       150
#      Potato___healthy       0.66      1.00      0.79        23
#
#              accuracy                           0.95       323
#             macro avg       0.88      0.96      0.91       323
#          weighted avg       0.96      0.95      0.95       323
#
#
# Classification report saved!
#
# Confusion matrix saved!
#
# Accuracy curve saved!
#
# Loss curve saved!
#
# Training Complete!
#
# Saved Files:
# - best_potato_resnet50.pth
# - full_resnet50_model.pth
# - confusion_matrix.png
# - classification_report.txt
# - accuracy_curve.png
# - loss_curve.png
